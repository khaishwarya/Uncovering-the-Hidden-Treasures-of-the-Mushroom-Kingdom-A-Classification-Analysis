# %%
# !nvidia-smi
# Out:
# Wed Jun  4 18:16:44 2025
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 566.36                 Driver Version: 566.36         CUDA Version: 12.7     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                  Driver-Model | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce GTX 1650      WDDM  |   00000000:01:00.0 Off |                  N/A |
# | N/A   73C    P0             18W /   50W |       0MiB /   4096MiB |      0%      Default |
# |                                         |                        |                  N/A |
# +-----------------------------------------+------------------------+----------------------+
#
# +-----------------------------------------------------------------------------------------+
# | Processes:                                                                              |
# |  GPU   GI   CI        PID   Type   Process name                              GPU Memory |
# |        ID   ID                                                               Usage      |
# |=========================================================================================|
# |  No running processes found                                                             |
# +-----------------------------------------------------------------------------------------+

# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from tensorflow import keras
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import VGG16, Xception, InceptionV3, ResNet50, DenseNet121
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# Set random seed for reproducibility
np.random.seed(42)
tf.random.set_seed(42)

#### Load and Preprocess Dataset ###

# Define data directories
train_dir = "Dataset/train"
test_dir = "Dataset/test"

# Define image size
img_size = (224, 224)

# Data augmentation and preprocessing
train_datagen = ImageDataGenerator(
    rescale=1./255,
    zoom_range=0.2,
    horizontal_flip=True,
    rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    fill_mode="nearest"
)

test_datagen = ImageDataGenerator(rescale=1./255)

# Load and preprocess training data
train_data = train_datagen.flow_from_directory(
    train_dir,
    target_size=img_size, #224x224
    class_mode="categorical",
    batch_size=100
)

# Load and preprocess test data
test_data = test_datagen.flow_from_directory(
    test_dir,
    target_size=img_size, #224x224
    class_mode="categorical",
    batch_size=100
)
#####

### Load Pre-trained InceptionV3 Model ###
base_model = InceptionV3(weights="imagenet", include_top=False, input_shape=(img_size[0], img_size[1], 3))
#####

###  Add Custom Layers ###
# Build transfer learning model 
model5 = Sequential()
model5.add(base_model)
model5.add(GlobalAveragePooling2D())
model5.add(Dense(100, activation="relu"))
model5.add(BatchNormalization())
model5.add(Dropout(0.5))
model5.add(Dense(100, activation="relu"))
model5.add(BatchNormalization())
model5.add(Dropout(0.5))
model5.add(Dense(17, activation="softmax"))

#####

### Freeze the pre-trained layers ###
for layer in base_model.layers:
    layer.trainable = False
####

### Compile the model ###
optimizer = Adam(learning_rate=0.001)
model5.compile(
    optimizer=optimizer,
    loss="categorical_crossentropy",
    metrics=["accuracy"]
)
####

# Early stopping
early_stop = EarlyStopping(
    monitor="val_loss",
    patience=5
)


###  Train the Model ###
history100 = model5.fit(train_data, epochs=50, validation_data=test_data, callbacks=[early_stop])
####

### Evaluate the model ###
loss, accuracy = model5.evaluate(test_data)
accuracy_percentage = accuracy * 100
print("Test loss:", loss)
print("Test accuracy:", accuracy_percentage)
# Out:
# Found 655 images belonging to 17 classes.
# Found 183 images belonging to 17 classes.
# Epoch 1/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 43s 5s/step - accuracy: 0.0723 - loss: 4.2900 - val_accuracy: 0.0765 - val_loss: 3.0379
# Epoch 2/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 34s 5s/step - accuracy: 0.1015 - loss: 3.6059 - val_accuracy: 0.0929 - val_loss: 3.2213
# Epoch 3/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.1354 - loss: 3.4251 - val_accuracy: 0.1093 - val_loss: 3.1176
# Epoch 4/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 34s 5s/step - accuracy: 0.1407 - loss: 3.1710 - val_accuracy: 0.1585 - val_loss: 2.8730
# Epoch 5/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 34s 5s/step - accuracy: 0.1501 - loss: 3.1974 - val_accuracy: 0.2404 - val_loss: 2.7118
# Epoch 6/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 34s 5s/step - accuracy: 0.1889 - loss: 3.0084 - val_accuracy: 0.2459 - val_loss: 2.6176
# Epoch 7/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 34s 5s/step - accuracy: 0.1913 - loss: 2.8745 - val_accuracy: 0.2623 - val_loss: 2.4870
# Epoch 8/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 36s 5s/step - accuracy: 0.2405 - loss: 2.6671 - val_accuracy: 0.2678 - val_loss: 2.4307
# Epoch 9/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 34s 5s/step - accuracy: 0.1999 - loss: 2.7282 - val_accuracy: 0.2951 - val_loss: 2.3494
# Epoch 10/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.2438 - loss: 2.6295 - val_accuracy: 0.2951 - val_loss: 2.2481
# Epoch 11/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 33s 5s/step - accuracy: 0.2402 - loss: 2.6522 - val_accuracy: 0.3333 - val_loss: 2.0792
# Epoch 12/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 34s 5s/step - accuracy: 0.2913 - loss: 2.5434 - val_accuracy: 0.3443 - val_loss: 1.9968
# Epoch 13/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 36s 5s/step - accuracy: 0.2599 - loss: 2.5388 - val_accuracy: 0.3770 - val_loss: 1.9143
# Epoch 14/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 37s 5s/step - accuracy: 0.3094 - loss: 2.3691 - val_accuracy: 0.4208 - val_loss: 1.8127
# Epoch 15/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 35s 5s/step - accuracy: 0.2856 - loss: 2.3412 - val_accuracy: 0.4973 - val_loss: 1.7460
# Epoch 16/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 41s 6s/step - accuracy: 0.3423 - loss: 2.1453 - val_accuracy: 0.5191 - val_loss: 1.6930
# Epoch 17/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 37s 5s/step - accuracy: 0.3603 - loss: 2.2550 - val_accuracy: 0.5246 - val_loss: 1.6783
# Epoch 18/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 35s 5s/step - accuracy: 0.3378 - loss: 2.1548 - val_accuracy: 0.5574 - val_loss: 1.6044
# Epoch 19/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 54s 8s/step - accuracy: 0.3537 - loss: 2.1595 - val_accuracy: 0.5027 - val_loss: 1.5711
# Epoch 20/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 42s 6s/step - accuracy: 0.3478 - loss: 2.1733 - val_accuracy: 0.5301 - val_loss: 1.5591
# Epoch 21/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 36s 5s/step - accuracy: 0.3441 - loss: 2.1775 - val_accuracy: 0.5792 - val_loss: 1.5287
# Epoch 22/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 44s 7s/step - accuracy: 0.3940 - loss: 1.9440 - val_accuracy: 0.6011 - val_loss: 1.4799
# Epoch 23/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 44s 6s/step - accuracy: 0.3685 - loss: 2.0619 - val_accuracy: 0.6393 - val_loss: 1.4402
# Epoch 24/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 44s 6s/step - accuracy: 0.3979 - loss: 1.9383 - val_accuracy: 0.6284 - val_loss: 1.4136
# Epoch 25/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 44s 6s/step - accuracy: 0.3814 - loss: 1.9867 - val_accuracy: 0.6339 - val_loss: 1.3713
# Epoch 26/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 38s 6s/step - accuracy: 0.4274 - loss: 1.8554 - val_accuracy: 0.6557 - val_loss: 1.3464
# Epoch 27/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 38s 5s/step - accuracy: 0.4052 - loss: 1.8739 - val_accuracy: 0.6230 - val_loss: 1.3053
# Epoch 28/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 37s 5s/step - accuracy: 0.4439 - loss: 1.7983 - val_accuracy: 0.6721 - val_loss: 1.2777
# Epoch 29/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 35s 5s/step - accuracy: 0.4415 - loss: 1.7933 - val_accuracy: 0.6393 - val_loss: 1.2669
# Epoch 30/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 35s 5s/step - accuracy: 0.4316 - loss: 1.8398 - val_accuracy: 0.6230 - val_loss: 1.2867
# Epoch 31/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 38s 5s/step - accuracy: 0.4390 - loss: 1.7917 - val_accuracy: 0.6339 - val_loss: 1.2524
# Epoch 32/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 39s 6s/step - accuracy: 0.4347 - loss: 1.7555 - val_accuracy: 0.6448 - val_loss: 1.1860
# Epoch 33/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 42s 6s/step - accuracy: 0.4768 - loss: 1.6806 - val_accuracy: 0.6776 - val_loss: 1.1288
# Epoch 34/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 37s 5s/step - accuracy: 0.4431 - loss: 1.7237 - val_accuracy: 0.7104 - val_loss: 1.0490
# Epoch 35/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 35s 5s/step - accuracy: 0.5076 - loss: 1.6749 - val_accuracy: 0.7432 - val_loss: 1.0136
# Epoch 36/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 36s 5s/step - accuracy: 0.4239 - loss: 1.6890 - val_accuracy: 0.7432 - val_loss: 1.0183
# Epoch 37/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 37s 5s/step - accuracy: 0.5184 - loss: 1.6688 - val_accuracy: 0.7322 - val_loss: 1.0302
# Epoch 38/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 42s 6s/step - accuracy: 0.5232 - loss: 1.5602 - val_accuracy: 0.7213 - val_loss: 1.0797
# Epoch 39/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 41s 6s/step - accuracy: 0.5183 - loss: 1.5741 - val_accuracy: 0.7213 - val_loss: 1.0991
# Epoch 40/50
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 36s 5s/step - accuracy: 0.5152 - loss: 1.5141 - val_accuracy: 0.7268 - val_loss: 1.0403
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 3s/step - accuracy: 0.7312 - loss: 1.0241
# Test loss: 1.040347695350647
# Test accuracy: 72.67759442329407

# %%
import matplotlib.pyplot as plt
import numpy as np
from tensorflow.keras.preprocessing import image

def predict(input_model):
  given_image = plt.imread(input_model)
  plt.imshow(given_image)
  inputImage = image.load_img(input_model, target_size=(224, 224))  # Adjust the target_size to (224, 224)
  inputImage = image.img_to_array(inputImage)
  inputImage = np.expand_dims(inputImage, axis=0)
  inputImage = inputImage / 255.0
  prediction = model5.predict(inputImage)
  predicted_class_index = np.argmax(prediction)
  class_names = list(train_data.class_indices.keys())
  predicted_class = class_names[predicted_class_index]
  print("The Mushroom image classification is:", predicted_class)

predict("Dataset/train/leukonychia/2.PNG")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# The Mushroom image classification is: leukonychia
